# %%
from astropy.table import Table
import matplotlib.pyplot as plt

# %%
data= Table.read("NGC2420.csv")
print(data)
# Out:
#       objid        run  rerun camcol ...    Err_r       Err_i       Err_z
# ------------------ ---- ----- ------ ... ----------- ----------- -----------
# 587732156849652388 2888    40      3 ...    0.018529    0.014122    0.032338
# 587732156849652389 2888    40      3 ...    0.020339    0.022057    0.074961
# 587732156849652386 2888    40      3 ...  0.00661835 0.007028737     0.01513
# 587732156849652390 2888    40      3 ...    0.075084    0.025883    0.051358
# 587732156849652391 2888    40      3 ...    0.446019    0.125061    0.196317
# 587732156849654242 2888    40      3 ...    0.320334    0.108147     0.23935
# 587732156849652250 2888    40      3 ...    0.011886    0.012951  0.00507519
# 587732156849652251 2888    40      3 ... 0.003650696    0.026829 0.004182646
# 587732156849652269 2888    40      3 ...  0.00393866 0.004399242 0.005136156
# 587732156849652270 2888    40      3 ... 0.004106498 0.004511362 0.005491005
# ...

# %%
g= data["g"]
r= data["r"]
colour=g-r
print(colour)
# Out:
#          g
# -------------------
#  1.6806240000000017
# 0.44401300000000177
#  0.7018050000000002
#  3.6481589999999997
#  0.8373139999999992
#  3.8181189999999994
# -0.3994339999999994
# 0.27592200000000133
# 0.29837700000000034
#  0.2658360000000002
#                 ...
#  1.7274719999999988
#  1.8675080000000008
#  1.5477729999999994
#   2.225950000000001
#  5.8491409999999995
#  0.9276450000000018
#  1.3774049999999995
#  0.7112729999999985
# -0.5880240000000008
#  1.8466609999999974
#  0.3619199999999978
# Length = 610 rows

# %%
plt.figure(figsize=(8,4))
plt.scatter(colour,g,s=2)
plt.grid()
plt.show()
