# %%
from astropy.table import Table
import matplotlib.pyplot as plt

# %%
data= Table.read("NGC2401.csv")
print(data)
# Out:
#       objid        run  rerun camcol ...    Err_r       Err_i       Err_z
# ------------------ ---- ----- ------ ... ----------- ----------- -----------
# 587750860901254511 7243    40      2 ...   0.0035033 0.003935897 0.004913971
# 587750860901254520 7243    40      2 ... 0.003738911 0.004120246 0.005582877
# 587750860901254500 7243    40      2 ... 0.003283998 0.003702132 0.003699571
# 587750860901254505 7243    40      2 ... 0.003473904 0.003880113 0.004291977
# 587750860901254512 7243    40      2 ... 0.003586978 0.004009172 0.004877235
# 587750860901254523 7243    40      2 ... 0.003807092 0.004193066 0.005939018
# 587750860901254501 7243    40      2 ... 0.003357554 0.003754495 0.003895039
# 587750860901254502 7243    40      2 ...  0.00342829 0.003808977 0.004026218
# 587750860901254516 7243    40      2 ... 0.003675809 0.004046996 0.005252288
# 587750860901254519 7243    40      2 ... 0.003370731  0.00373896 0.004923996
# ...

# %%
g= data["g"]
r= data["r"]
colour=g-r
print(colour)
# Out:
#           g
# ---------------------
#  0.055619000000000085
#   0.20055699999999987
# 0.0003470000000014295
#   0.06666900000000098
#   0.12514499999999984
#    0.1851680000000009
#  0.017908000000000257
#  0.009749000000001118
#   0.07856999999999914
#   0.15920700000000032
#                   ...
#    0.7669360000000012
#    1.0045750000000027
#    1.7604560000000014
#    0.6507259999999988
#              1.720319
#     1.158449000000001
#    0.9880460000000006
#    0.8241839999999989
#    3.0558510000000005
#    1.2449629999999985
#    2.3691540000000018
# Length = 1122 rows

# %%
plt.figure(figsize=(8,4))
plt.scatter(colour,g,s=2)
plt.grid()
plt.show()
