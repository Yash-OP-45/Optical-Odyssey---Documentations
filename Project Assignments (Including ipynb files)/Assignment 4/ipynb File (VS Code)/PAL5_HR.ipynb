# %%
from astropy.table import Table
import matplotlib.pyplot as plt

# %%
data= Table.read("Pal5.csv")
print(data)
# Out:
#       objid        run rerun camcol ...    Err_r       Err_i     Err_z
# ------------------ --- ----- ------ ... ----------- ----------- --------
# 588848899934127355 756    44      3 ...     0.04478    0.061636   0.1789
# 588848899934127356 756    44      3 ...    0.060524    0.091566 0.346587
# 588848899934126390 756    44      3 ...    0.024637    0.032656 0.133019
# 588848899934127350 756    44      3 ...    0.023276    0.029138 0.106125
# 588848899934127354 756    44      3 ...    0.036799    0.045061 0.166965
# 588848899934129440 756    44      3 ...    0.195619    0.416286 0.679807
# 588848899934126374 756    44      3 ... 0.005727568 0.006092031 0.013778
# 588848899934126382 756    44      3 ...    0.068407    0.023337  0.05167
# 588848899934126389 756    44      3 ...    0.023586    0.030155 0.097919
# 588848899934126529 756    44      3 ...  0.00490187 0.005431115 0.012005
#                ... ...   ...    ... ...         ...         ...      ...
# ...

# %%
g= data["g"]
r= data["r"]
colour=g-r
print(colour)
# Out:
#          g
# -------------------
#  0.4442750000000011
#  0.3901639999999986
# 0.34690900000000013
# 0.30922100000000086
# 0.35490000000000066
#  1.3619839999999996
#  0.6443750000000001
#  2.2614829999999984
#  0.3727930000000015
#  0.3192009999999996
#                 ...
#  0.9445569999999996
#  0.7514229999999991
#  0.6686650000000007
#  1.4501480000000022
#  1.0182420000000008
#  1.2972540000000023
#  0.6525579999999991
#  1.1915869999999984
#  0.5369920000000015
#            1.667116
#  1.2754259999999995
# Length = 1188 rows

# %%
plt.figure(figsize=(8,4))
plt.scatter(colour,g,s=2)
plt.grid()
plt.show()
